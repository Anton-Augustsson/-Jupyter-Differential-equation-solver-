# %%
import numpy as np
import matplotlib.pyplot as plt
import random
# %matplotlib inline

# %%
# y' + uy = zx² + qx + k
# y(0) = w
e = -4
f = 2
g = 2
h = 4
i = 15

def funktion(a, b, c, d, e, result):
    x = np.linspace(0,20)
    y = d * np.exp(-1 * e * x) + a * x * x + b * x + c
    plt.figure()
    plt.plot(x,y,label=result)
    plt.legend()
    
def difsolv(e, f, g, h, i):
    d = (i-((h-(q-(2*f/e)/e))/e))#str(u * u * u * w - u * u * k - u * q - 2 * z) + '/' + str(u * u * u)#
    a = (f/e)
    b = (g-(2*f/e)/e)
    c = ((h-(g-(2*f/e)/e))/e)
    result = str('y(x) = ' + str(d) + 'e^'+ str(-1 * e) + 'x + ' + str(a) + 'x² + ' + str(b) + 'x + ' + str(c))
    funktion(e, d, a, b, c, result)

        
    
    
difsolv(u,z,q,k,w)
